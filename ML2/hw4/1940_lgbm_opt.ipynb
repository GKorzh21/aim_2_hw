# %%
def custom_epsilon_loss_grad_hess(y_raw, tr_data=None, y_true=None, alpha=1.2, beta=0.9, epsilon=1, p=2):
    """
    Улучшенная версия epsilon-insensitive asymmetric loss с диагностикой.
    """
    # Получаем истинные значения
    if y_true is None:
        y_true = tr_data.get_label()
    
    # Проверка размерностей
    assert len(y_raw) == len(y_true), f"Размеры не совпадают: y_raw {len(y_raw)}, y_true {len(y_true)}"
    
    residuals = y_raw - y_true
    
    # Диагностика: выводим статистику по остаткам
    #print("\nДиагностика лосса:")
    #print(f"Сырые предсказания: min={np.min(y_raw):.2f}, max={np.max(y_raw):.2f}")
    #print(f"Истинные значения: min={np.min(y_true):.2f}, max={np.max(y_true):.2f}")
    #print(f"Остатки: min={np.min(residuals):.2f}, max={np.max(residuals):.2f}")
    
    # Инициализация градиента и гессиана
    grad = np.zeros_like(residuals)
    hess = np.zeros_like(residuals)
    
    # Маски для разных случаев
    within_epsilon = np.abs(residuals) <= epsilon
    overestimation = residuals > epsilon
    underestimation = residuals < -epsilon
    
    #print(f"Точек в epsilon: {np.sum(within_epsilon)}")
    #print(f"Переоценок: {np.sum(overestimation)}")
    #print(f"Недооценок: {np.sum(underestimation)}")
    
    # Вычисление градиента
    grad[overestimation] = alpha * p * (residuals[overestimation] - epsilon)**(p-1)
    grad[underestimation] = -beta * p * (-residuals[underestimation] - epsilon)**(p-1)
    
    # Вычисление гессиана
    if p > 1:
        hess[overestimation] = alpha * p * (p-1) * (residuals[overestimation] - epsilon)**(p-2)
        hess[underestimation] = beta * p * (p-1) * (-residuals[underestimation] - epsilon)**(p-2)
    
    # Защита от численной нестабильности
    grad = np.nan_to_num(grad, nan=0.0, posinf=0.0, neginf=0.0)
    hess = np.nan_to_num(hess, nan=0.0, posinf=0.0, neginf=0.0)
    
    #print(f"Градиент: min={np.min(grad):.2f}, max={np.max(grad):.2f}")
    #print(f"Гессиан: min={np.min(hess):.2f}, max={np.max(hess):.2f}")
    
    return grad, hess

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import KFold
from sklearn.preprocessing import TargetEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import seaborn as sns
import optuna
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from functools import partial


import warnings
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# Загрузка данных
train = pd.read_csv('train_contest.csv')
test = pd.read_csv('test_contest.csv')

# Подготовка данных
features = list(train.drop('target', axis=1).columns)
cat_features = train.select_dtypes(include=['object', 'category']).columns.tolist()

for feat in cat_features:
    train[feat] = train[feat].astype('category')
    test[feat] = test[feat].astype('category')

# Разделение данных для валидации
X_train, X_val, y_train, y_val = train_test_split(
    train[features], train['target'], test_size=0.2, random_state=42
)

# Создание Dataset для LightGBM
train_dataset = lgb.Dataset(X_train, label=y_train, categorical_feature=cat_features)
val_dataset = lgb.Dataset(X_val, label=y_val, categorical_feature=cat_features, reference=train_dataset)

# Функция для оптимизации через Optuna
def objective(trial):
    params = {
        'objective': partial(custom_epsilon_loss_grad_hess,
                       alpha=1.4,     # штраф за переоценку
                       beta=1.55,      # УВЕЛИЧЕННЫЙ штраф за недооценку
                       epsilon=25,
                       p=1.83          # Более близко к L2
    	),
        'metric': 'rmse',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'feature_pre_filter': False,
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0, log=True),
    }
    
    model = lgb.train(
        params,
        train_dataset,
        valid_sets=[val_dataset],
        callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
    )
    
    preds = model.predict(X_val)
    mse = mean_squared_error(y_val, preds)
    rmse = np.sqrt(mse)  # Вручную вычисляем RMSE, если параметр squared не поддерживается
    
    return rmse

# Оптимизация гиперпараметров
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=150, timeout=2*60*60)

print('Best trial:')
trial = study.best_trial
print(f'  RMSE: {trial.value}')
print('  Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')

# Обучение модели с лучшими параметрами на всех данных
best_params = trial.params
best_params['objective'] = 'regression'

full_train_dataset = lgb.Dataset(train[features], label=train['target'], categorical_feature=cat_features)
final_model = lgb.train(best_params, full_train_dataset)

# Предсказание на тестовых данных
test['target'] = final_model.predict(test[features])
test[['index', 'target']].to_csv('test.csv', index=False)
# Out:
# [I 2025-05-06 17:49:55,272] A new study created in memory with name: no-name-90f54a2c-cb4f-4d4d-8768-4e650d583fc3
# [I 2025-05-06 17:49:57,282] Trial 0 finished with value: 1877.229658514508 and parameters: {'num_leaves': 181, 'learning_rate': 0.07545449094242128, 'feature_fraction': 0.5193764937602081, 'bagging_fraction': 0.9637123953212995, 'bagging_freq': 7, 'min_child_samples': 99, 'lambda_l1': 0.003977933352850825, 'lambda_l2': 9.416876841992265e-08}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:49:58,958] Trial 1 finished with value: 1884.1471299442544 and parameters: {'num_leaves': 212, 'learning_rate': 0.08869632352789596, 'feature_fraction': 0.5842007441742708, 'bagging_fraction': 0.7034361308411357, 'bagging_freq': 1, 'min_child_samples': 31, 'lambda_l1': 8.339236350051185e-07, 'lambda_l2': 0.00474674985130095}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:01,111] Trial 2 finished with value: 1891.9130494705055 and parameters: {'num_leaves': 290, 'learning_rate': 0.06656561457584628, 'feature_fraction': 0.9856308371311046, 'bagging_fraction': 0.7200190960606256, 'bagging_freq': 2, 'min_child_samples': 83, 'lambda_l1': 6.52009267333115e-06, 'lambda_l2': 0.11478758680220634}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:02,901] Trial 3 finished with value: 1889.1627451117051 and parameters: {'num_leaves': 271, 'learning_rate': 0.06476654357023169, 'feature_fraction': 0.5502896776762309, 'bagging_fraction': 0.6431386846131919, 'bagging_freq': 2, 'min_child_samples': 9, 'lambda_l1': 1.3903981287909244e-07, 'lambda_l2': 9.483106406424864e-06}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:04,026] Trial 4 finished with value: 1882.6356466996594 and parameters: {'num_leaves': 39, 'learning_rate': 0.08682668599706397, 'feature_fraction': 0.40372580593599866, 'bagging_fraction': 0.7275145224436806, 'bagging_freq': 6, 'min_child_samples': 16, 'lambda_l1': 0.792244206156169, 'lambda_l2': 0.022983651386744876}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:05,799] Trial 5 finished with value: 1921.8933464775362 and parameters: {'num_leaves': 187, 'learning_rate': 0.02813840085042234, 'feature_fraction': 0.4142073447756965, 'bagging_fraction': 0.9837999904068543, 'bagging_freq': 2, 'min_child_samples': 44, 'lambda_l1': 0.11014610022482721, 'lambda_l2': 0.03808361226864366}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:07,672] Trial 6 finished with value: 1933.691126506559 and parameters: {'num_leaves': 277, 'learning_rate': 0.026427903575915346, 'feature_fraction': 0.5765942106498649, 'bagging_fraction': 0.6944805246661067, 'bagging_freq': 7, 'min_child_samples': 71, 'lambda_l1': 0.1525478627041452, 'lambda_l2': 1.7280981815669332e-06}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:09,033] Trial 7 finished with value: 1878.2088058072047 and parameters: {'num_leaves': 92, 'learning_rate': 0.07862689200332891, 'feature_fraction': 0.63789566951512, 'bagging_fraction': 0.6127121629289721, 'bagging_freq': 7, 'min_child_samples': 39, 'lambda_l1': 0.0014615346338797955, 'lambda_l2': 5.791953707477977e-07}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:10,463] Trial 8 finished with value: 1881.2654152107327 and parameters: {'num_leaves': 87, 'learning_rate': 0.05651627352250119, 'feature_fraction': 0.9077028901428672, 'bagging_fraction': 0.6673842111064858, 'bagging_freq': 2, 'min_child_samples': 14, 'lambda_l1': 1.1097575961188562e-08, 'lambda_l2': 9.616686897113687e-08}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:12,491] Trial 9 finished with value: 1893.0596352043358 and parameters: {'num_leaves': 259, 'learning_rate': 0.07944512905709625, 'feature_fraction': 0.7409004498165284, 'bagging_fraction': 0.7071040619547333, 'bagging_freq': 5, 'min_child_samples': 97, 'lambda_l1': 6.493114069993165e-07, 'lambda_l2': 7.266735296747265e-08}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:14,221] Trial 10 finished with value: 1889.0146099234178 and parameters: {'num_leaves': 134, 'learning_rate': 0.042533920989977776, 'feature_fraction': 0.7764731125005027, 'bagging_fraction': 0.9918201848533015, 'bagging_freq': 4, 'min_child_samples': 63, 'lambda_l1': 0.0005964442795952732, 'lambda_l2': 0.00016723316305089665}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:15,296] Trial 11 finished with value: 3114.296463897972 and parameters: {'num_leaves': 124, 'learning_rate': 0.004489304541086966, 'feature_fraction': 0.6386120873342029, 'bagging_fraction': 0.4531777919710069, 'bagging_freq': 7, 'min_child_samples': 45, 'lambda_l1': 0.0009551693199668043, 'lambda_l2': 8.819983480322112}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:16,726] Trial 12 finished with value: 1880.3436280550393 and parameters: {'num_leaves': 75, 'learning_rate': 0.0986438333970267, 'feature_fraction': 0.4981987650748262, 'bagging_fraction': 0.8628851983116632, 'bagging_freq': 5, 'min_child_samples': 59, 'lambda_l1': 0.004546767974176693, 'lambda_l2': 1.098353705432733e-08}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:18,375] Trial 13 finished with value: 1893.9276721589624 and parameters: {'num_leaves': 172, 'learning_rate': 0.07593311681450914, 'feature_fraction': 0.6837606115304224, 'bagging_fraction': 0.5194553542975314, 'bagging_freq': 6, 'min_child_samples': 32, 'lambda_l1': 3.883081773476831e-05, 'lambda_l2': 1.0577577666320535e-05}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:19,690] Trial 14 finished with value: 1928.7869847386753 and parameters: {'num_leaves': 21, 'learning_rate': 0.04901999595817101, 'feature_fraction': 0.4851031932835488, 'bagging_fraction': 0.857613032656156, 'bagging_freq': 7, 'min_child_samples': 98, 'lambda_l1': 0.010319535784654341, 'lambda_l2': 5.851454044546286e-07}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:21,474] Trial 15 finished with value: 1894.9435087854906 and parameters: {'num_leaves': 213, 'learning_rate': 0.09659769640261393, 'feature_fraction': 0.7847300490550229, 'bagging_fraction': 0.5736300257814784, 'bagging_freq': 4, 'min_child_samples': 76, 'lambda_l1': 3.9510113040970056, 'lambda_l2': 0.0001908127016379542}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:22,989] Trial 16 finished with value: 1880.6429597439985 and parameters: {'num_leaves': 123, 'learning_rate': 0.07164302047370845, 'feature_fraction': 0.6772272165807366, 'bagging_fraction': 0.8249448483511518, 'bagging_freq': 6, 'min_child_samples': 29, 'lambda_l1': 5.513948348404882e-05, 'lambda_l2': 1.674250282400181e-05}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:24,299] Trial 17 finished with value: 1881.7671487276752 and parameters: {'num_leaves': 76, 'learning_rate': 0.060529878930570054, 'feature_fraction': 0.826944694785952, 'bagging_fraction': 0.5936900494825115, 'bagging_freq': 5, 'min_child_samples': 47, 'lambda_l1': 0.0027511375384685604, 'lambda_l2': 1.9041016971363477e-08}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:25,927] Trial 18 finished with value: 1882.6020963340086 and parameters: {'num_leaves': 149, 'learning_rate': 0.08486365040300908, 'feature_fraction': 0.6326452050306888, 'bagging_fraction': 0.7743188586427647, 'bagging_freq': 7, 'min_child_samples': 86, 'lambda_l1': 0.022459210497178222, 'lambda_l2': 5.724530841663601e-07}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:27,429] Trial 19 finished with value: 1898.1586822193665 and parameters: {'num_leaves': 103, 'learning_rate': 0.03771469815737971, 'feature_fraction': 0.4912120396835088, 'bagging_fraction': 0.9229861936027447, 'bagging_freq': 6, 'min_child_samples': 62, 'lambda_l1': 0.00020800057262170357, 'lambda_l2': 1.8462544854195247e-07}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:29,088] Trial 20 finished with value: 1890.815612019724 and parameters: {'num_leaves': 238, 'learning_rate': 0.07680928467696838, 'feature_fraction': 0.5406358668570249, 'bagging_fraction': 0.4779099880313526, 'bagging_freq': 3, 'min_child_samples': 22, 'lambda_l1': 0.03219905034779194, 'lambda_l2': 0.0011716429578605188}. Best is trial 0 with value: 1877.229658514508.
# [I 2025-05-06 17:50:30,424] Trial 21 finished with value: 1876.1525723312654 and parameters: {'num_leaves': 60, 'learning_rate': 0.09946492496276951, 'feature_fraction': 0.48080663149378566, 'bagging_fraction': 0.9132527028475281, 'bagging_freq': 5, 'min_child_samples': 62, 'lambda_l1': 0.0031369286865503172, 'lambda_l2': 1.1765456082538169e-08}. Best is trial 21 with value: 1876.1525723312654.
# [I 2025-05-06 17:50:31,733] Trial 22 finished with value: 1871.0005966363613 and parameters: {'num_leaves': 58, 'learning_rate': 0.09485339961200664, 'feature_fraction': 0.45832637974494206, 'bagging_fraction': 0.9224612641705252, 'bagging_freq': 5, 'min_child_samples': 53, 'lambda_l1': 9.826715391965029e-05, 'lambda_l2': 1.0124000189914733e-08}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:33,034] Trial 23 finished with value: 1873.0713551239644 and parameters: {'num_leaves': 56, 'learning_rate': 0.09969927468924378, 'feature_fraction': 0.4375245993792343, 'bagging_fraction': 0.9454320952249387, 'bagging_freq': 5, 'min_child_samples': 55, 'lambda_l1': 9.32475379043632e-05, 'lambda_l2': 3.054645772832963e-08}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:34,341] Trial 24 finished with value: 1874.0203850693945 and parameters: {'num_leaves': 52, 'learning_rate': 0.09470982609628531, 'feature_fraction': 0.4492081423835957, 'bagging_fraction': 0.9204693933720189, 'bagging_freq': 5, 'min_child_samples': 55, 'lambda_l1': 1.4131657102461406e-05, 'lambda_l2': 1.0546882820708156e-08}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:35,622] Trial 25 finished with value: 1873.4105803104535 and parameters: {'num_leaves': 53, 'learning_rate': 0.0908017185517802, 'feature_fraction': 0.4391038833358878, 'bagging_fraction': 0.9201597915733966, 'bagging_freq': 4, 'min_child_samples': 52, 'lambda_l1': 8.661429117413423e-06, 'lambda_l2': 3.571331709746249e-08}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:36,759] Trial 26 finished with value: 1888.6722994269596 and parameters: {'num_leaves': 21, 'learning_rate': 0.08844432595590278, 'feature_fraction': 0.4380138343982624, 'bagging_fraction': 0.796136831867128, 'bagging_freq': 3, 'min_child_samples': 53, 'lambda_l1': 3.7333305033037165e-06, 'lambda_l2': 3.322045072869701e-06}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:38,071] Trial 27 finished with value: 1875.3102310289553 and parameters: {'num_leaves': 49, 'learning_rate': 0.09099111917578381, 'feature_fraction': 0.4561282793300606, 'bagging_fraction': 0.873336458736217, 'bagging_freq': 4, 'min_child_samples': 71, 'lambda_l1': 0.00010784981290502249, 'lambda_l2': 5.386191587752504e-08}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:39,559] Trial 28 finished with value: 1872.6295740598964 and parameters: {'num_leaves': 109, 'learning_rate': 0.08570576429577534, 'feature_fraction': 0.40396774901350757, 'bagging_fraction': 0.9438478043149621, 'bagging_freq': 3, 'min_child_samples': 38, 'lambda_l1': 1.1430238314045483e-06, 'lambda_l2': 3.8423257897507496e-05}. Best is trial 22 with value: 1871.0005966363613.
# [I 2025-05-06 17:50:41,022] Trial 29 finished with value: 1869.3040754614983 and parameters: {'num_leaves': 108, 'learning_rate': 0.08276046069491169, 'feature_fraction': 0.40057068818792335, 'bagging_fraction': 0.9527515880825218, 'bagging_freq': 3, 'min_child_samples': 38, 'lambda_l1': 1.8743968761327903e-07, 'lambda_l2': 6.337819048761424e-05}. Best is trial 29 with value: 1869.3040754614983.
# [I 2025-05-06 17:50:42,667] Trial 30 finished with value: 1878.4060738972394 and parameters: {'num_leaves': 108, 'learning_rate': 0.06856355671622659, 'feature_fraction': 0.5398680011447305, 'bagging_fraction': 0.9575175835786793, 'bagging_freq': 3, 'min_child_samples': 37, 'lambda_l1': 1.0896706974645792e-08, 'lambda_l2': 3.9345466134744055e-05}. Best is trial 29 with value: 1869.3040754614983.
# [I 2025-05-06 17:50:44,234] Trial 31 finished with value: 1871.919408015968 and parameters: {'num_leaves': 147, 'learning_rate': 0.08253798439627699, 'feature_fraction': 0.40022131627727026, 'bagging_fraction': 0.9611692772966737, 'bagging_freq': 3, 'min_child_samples': 39, 'lambda_l1': 5.6041669306646325e-08, 'lambda_l2': 5.222684174702321e-05}. Best is trial 29 with value: 1869.3040754614983.
# [I 2025-05-06 17:50:45,819] Trial 32 finished with value: 1871.9875536629715 and parameters: {'num_leaves': 146, 'learning_rate': 0.08297261216260267, 'feature_fraction': 0.4084795787927324, 'bagging_fraction': 0.9975188763387902, 'bagging_freq': 3, 'min_child_samples': 25, 'lambda_l1': 7.15647234139704e-08, 'lambda_l2': 0.001006666088631053}. Best is trial 29 with value: 1869.3040754614983.
# [I 2025-05-06 17:50:47,278] Trial 33 finished with value: 1868.0029121498944 and parameters: {'num_leaves': 152, 'learning_rate': 0.08052343273480138, 'feature_fraction': 0.4000390139268459, 'bagging_fraction': 0.998980122163024, 'bagging_freq': 1, 'min_child_samples': 31, 'lambda_l1': 7.825987826691147e-08, 'lambda_l2': 0.0010438218137118107}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:48,920] Trial 34 finished with value: 1874.2840080817832 and parameters: {'num_leaves': 195, 'learning_rate': 0.07075209492885692, 'feature_fraction': 0.5150751850011223, 'bagging_fraction': 0.8639243157448271, 'bagging_freq': 1, 'min_child_samples': 34, 'lambda_l1': 1.398610280745079e-07, 'lambda_l2': 0.00643045841674271}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:50,459] Trial 35 finished with value: 1877.390877578789 and parameters: {'num_leaves': 164, 'learning_rate': 0.09321617263408173, 'feature_fraction': 0.4670565539727874, 'bagging_fraction': 0.8889767420735201, 'bagging_freq': 1, 'min_child_samples': 23, 'lambda_l1': 5.205870135571691e-08, 'lambda_l2': 4.179783110006792}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:52,202] Trial 36 finished with value: 1874.8621982866628 and parameters: {'num_leaves': 143, 'learning_rate': 0.06271923740247498, 'feature_fraction': 0.5787872250871253, 'bagging_fraction': 0.9735109410236922, 'bagging_freq': 2, 'min_child_samples': 43, 'lambda_l1': 4.045742171969336e-07, 'lambda_l2': 0.0006507041857489053}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:53,794] Trial 37 finished with value: 1873.3933806891382 and parameters: {'num_leaves': 197, 'learning_rate': 0.0823518295506696, 'feature_fraction': 0.4004857927374366, 'bagging_fraction': 0.8247277141105074, 'bagging_freq': 1, 'min_child_samples': 28, 'lambda_l1': 1.8147620824050624e-06, 'lambda_l2': 0.398774652702382}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:55,409] Trial 38 finished with value: 1875.384150949511 and parameters: {'num_leaves': 160, 'learning_rate': 0.07305285430547151, 'feature_fraction': 0.5221221214151007, 'bagging_fraction': 0.7676038501773381, 'bagging_freq': 2, 'min_child_samples': 8, 'lambda_l1': 3.298998023747312e-08, 'lambda_l2': 0.00416867642589482}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:56,903] Trial 39 finished with value: 1881.9910592241017 and parameters: {'num_leaves': 125, 'learning_rate': 0.054776759619899876, 'feature_fraction': 0.4316784522877791, 'bagging_fraction': 0.9634165761298329, 'bagging_freq': 4, 'min_child_samples': 18, 'lambda_l1': 2.4003840162464005e-07, 'lambda_l2': 6.142574434969668e-05}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:58,297] Trial 40 finished with value: 3670.0851672179865 and parameters: {'num_leaves': 94, 'learning_rate': 0.0016820086909756574, 'feature_fraction': 0.9763944144098722, 'bagging_fraction': 0.8923448709782439, 'bagging_freq': 2, 'min_child_samples': 47, 'lambda_l1': 1.9934691078216035e-08, 'lambda_l2': 0.14093512905752337}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:50:59,882] Trial 41 finished with value: 1869.8813490546067 and parameters: {'num_leaves': 151, 'learning_rate': 0.08210389857930475, 'feature_fraction': 0.40294163508307035, 'bagging_fraction': 0.9959519836055746, 'bagging_freq': 3, 'min_child_samples': 26, 'lambda_l1': 6.167728043884486e-08, 'lambda_l2': 0.0032093781644610586}. Best is trial 33 with value: 1868.0029121498944.
# [I 2025-05-06 17:51:01,656] Trial 42 finished with value: 1867.7643421959476 and parameters: {'num_leaves': 180, 'learning_rate': 0.07885918772343231, 'feature_fraction': 0.4616995957795667, 'bagging_fraction': 0.9970498742148566, 'bagging_freq': 3, 'min_child_samples': 41, 'lambda_l1': 9.013502414952985e-08, 'lambda_l2': 0.002860192358045248}. Best is trial 42 with value: 1867.7643421959476.
# [I 2025-05-06 17:51:03,475] Trial 43 finished with value: 1878.0906975764078 and parameters: {'num_leaves': 215, 'learning_rate': 0.07776042076652252, 'feature_fraction': 0.4663229085991083, 'bagging_fraction': 0.9951570877547592, 'bagging_freq': 3, 'min_child_samples': 14, 'lambda_l1': 1.8984292462512263e-07, 'lambda_l2': 0.009153730520248874}. Best is trial 42 with value: 1867.7643421959476.
# [I 2025-05-06 17:51:05,300] Trial 44 finished with value: 1873.496383537321 and parameters: {'num_leaves': 185, 'learning_rate': 0.06496350388475913, 'feature_fraction': 0.5161534155915556, 'bagging_fraction': 0.9988386821247573, 'bagging_freq': 2, 'min_child_samples': 34, 'lambda_l1': 2.369850266095714e-06, 'lambda_l2': 0.002902676135963244}. Best is trial 42 with value: 1867.7643421959476.
# [I 2025-05-06 17:51:06,921] Trial 45 finished with value: 2285.6587490544093 and parameters: {'num_leaves': 175, 'learning_rate': 0.011438760590906101, 'feature_fraction': 0.6038187945098322, 'bagging_fraction': 0.9379246150956466, 'bagging_freq': 4, 'min_child_samples': 42, 'lambda_l1': 6.640241574464663e-07, 'lambda_l2': 0.030624813515997558}. Best is trial 42 with value: 1867.7643421959476.
# [I 2025-05-06 17:51:08,334] Trial 46 finished with value: 1866.949954410061 and parameters: {'num_leaves': 71, 'learning_rate': 0.08783752197742956, 'feature_fraction': 0.42995386230997445, 'bagging_fraction': 0.899494843450374, 'bagging_freq': 2, 'min_child_samples': 49, 'lambda_l1': 2.203426342503105e-08, 'lambda_l2': 0.0004567262659503128}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:09,747] Trial 47 finished with value: 1872.0316692498293 and parameters: {'num_leaves': 134, 'learning_rate': 0.08069984292992406, 'feature_fraction': 0.4285794794736716, 'bagging_fraction': 0.8948417992956027, 'bagging_freq': 1, 'min_child_samples': 27, 'lambda_l1': 9.693789843490378e-08, 'lambda_l2': 0.00031626218817961847}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:11,692] Trial 48 finished with value: 1877.0717584789033 and parameters: {'num_leaves': 235, 'learning_rate': 0.08766737746139663, 'feature_fraction': 0.49742638741726475, 'bagging_fraction': 0.9706890899670726, 'bagging_freq': 2, 'min_child_samples': 48, 'lambda_l1': 2.292833433723416e-08, 'lambda_l2': 0.002142949583534978}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:13,128] Trial 49 finished with value: 1872.4610393271316 and parameters: {'num_leaves': 77, 'learning_rate': 0.07339046724898275, 'feature_fraction': 0.5544091212720483, 'bagging_fraction': 0.8366575492132479, 'bagging_freq': 2, 'min_child_samples': 32, 'lambda_l1': 4.316271485806615e-07, 'lambda_l2': 0.010498188888073863}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:14,638] Trial 50 finished with value: 1876.5580854800635 and parameters: {'num_leaves': 166, 'learning_rate': 0.06712728044973584, 'feature_fraction': 0.4288248707633952, 'bagging_fraction': 0.9646182358781916, 'bagging_freq': 1, 'min_child_samples': 18, 'lambda_l1': 1.089307777961867e-08, 'lambda_l2': 0.00028259204671973504}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:15,882] Trial 51 finished with value: 1882.62107220939 and parameters: {'num_leaves': 33, 'learning_rate': 0.09299031329298413, 'feature_fraction': 0.4630995642294416, 'bagging_fraction': 0.939072869981946, 'bagging_freq': 3, 'min_child_samples': 50, 'lambda_l1': 2.543648003297254e-07, 'lambda_l2': 0.0005376090794470202}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:17,091] Trial 52 finished with value: 1882.6323412550216 and parameters: {'num_leaves': 71, 'learning_rate': 0.08715654930526281, 'feature_fraction': 0.42185479887542265, 'bagging_fraction': 0.4073230789801729, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 2.5466217170703547e-08, 'lambda_l2': 0.07313200329948034}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:18,559] Trial 53 finished with value: 1871.4468215046747 and parameters: {'num_leaves': 86, 'learning_rate': 0.0780215724495547, 'feature_fraction': 0.47187553363990237, 'bagging_fraction': 0.9833680803302837, 'bagging_freq': 3, 'min_child_samples': 58, 'lambda_l1': 1.8871400291720817e-05, 'lambda_l2': 9.38491007509382e-05}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:20,078] Trial 54 finished with value: 1869.557724757759 and parameters: {'num_leaves': 115, 'learning_rate': 0.08997351685923043, 'feature_fraction': 0.4545422411747679, 'bagging_fraction': 0.9175308018249058, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 1.0221571634725551e-07, 'lambda_l2': 0.019498383063124958}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:21,600] Trial 55 finished with value: 1871.4628346844381 and parameters: {'num_leaves': 117, 'learning_rate': 0.08034350000918421, 'feature_fraction': 0.49994775984292894, 'bagging_fraction': 0.9022090006309347, 'bagging_freq': 4, 'min_child_samples': 36, 'lambda_l1': 1.0225081953529975e-07, 'lambda_l2': 0.001971371284441436}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:23,082] Trial 56 finished with value: 1881.579094616974 and parameters: {'num_leaves': 133, 'learning_rate': 0.07526984094349458, 'feature_fraction': 0.7193774779012044, 'bagging_fraction': 0.6548267898604765, 'bagging_freq': 3, 'min_child_samples': 31, 'lambda_l1': 4.0734742834151314e-08, 'lambda_l2': 0.01671519800791093}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:24,860] Trial 57 finished with value: 1883.1627453988258 and parameters: {'num_leaves': 153, 'learning_rate': 0.08515334397586233, 'feature_fraction': 0.8861374808432382, 'bagging_fraction': 0.8446378249556697, 'bagging_freq': 2, 'min_child_samples': 22, 'lambda_l1': 3.6183976785909344e-07, 'lambda_l2': 0.33792832392746025}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:26,271] Trial 58 finished with value: 1880.0487087893841 and parameters: {'num_leaves': 104, 'learning_rate': 0.09060345871345879, 'feature_fraction': 0.4173029485499476, 'bagging_fraction': 0.741268127835955, 'bagging_freq': 4, 'min_child_samples': 40, 'lambda_l1': 1.2404827670005637e-07, 'lambda_l2': 0.00016571724296404085}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:27,880] Trial 59 finished with value: 1873.614484987076 and parameters: {'num_leaves': 94, 'learning_rate': 0.05794600575152099, 'feature_fraction': 0.44843801672734623, 'bagging_fraction': 0.9358282258761003, 'bagging_freq': 3, 'min_child_samples': 35, 'lambda_l1': 9.487055995405962e-07, 'lambda_l2': 0.0009849740302100914}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:29,465] Trial 60 finished with value: 1885.300821021229 and parameters: {'num_leaves': 116, 'learning_rate': 0.047243384320541724, 'feature_fraction': 0.48056467465873415, 'bagging_fraction': 0.8811175634243045, 'bagging_freq': 1, 'min_child_samples': 45, 'lambda_l1': 3.952444521658252e-06, 'lambda_l2': 1.7749210732753993e-05}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:30,851] Trial 61 finished with value: 1876.3950059599679 and parameters: {'num_leaves': 65, 'learning_rate': 0.09681536989333515, 'feature_fraction': 0.42074729101889896, 'bagging_fraction': 0.9108925864558036, 'bagging_freq': 6, 'min_child_samples': 67, 'lambda_l1': 4.952049521302689, 'lambda_l2': 0.06159663263609845}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:32,164] Trial 62 finished with value: 1874.1799413313393 and parameters: {'num_leaves': 40, 'learning_rate': 0.09444419378865535, 'feature_fraction': 0.4482053587757315, 'bagging_fraction': 0.9515228315572398, 'bagging_freq': 5, 'min_child_samples': 48, 'lambda_l1': 0.2622636984415069, 'lambda_l2': 2.0092461080152747e-06}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:33,905] Trial 63 finished with value: 1868.9810700705332 and parameters: {'num_leaves': 175, 'learning_rate': 0.08943156618768358, 'feature_fraction': 0.4582013081039715, 'bagging_fraction': 0.9850711349587071, 'bagging_freq': 4, 'min_child_samples': 30, 'lambda_l1': 1.7314180592388635e-08, 'lambda_l2': 0.016578525049221887}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:35,669] Trial 64 finished with value: 1871.357263587666 and parameters: {'num_leaves': 177, 'learning_rate': 0.08992677600807314, 'feature_fraction': 0.48833122121080746, 'bagging_fraction': 0.9838442764924223, 'bagging_freq': 4, 'min_child_samples': 31, 'lambda_l1': 2.3485930591386268e-08, 'lambda_l2': 0.014742611057850782}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:37,430] Trial 65 finished with value: 1876.8766571821345 and parameters: {'num_leaves': 193, 'learning_rate': 0.08379929936166099, 'feature_fraction': 0.41812342493571164, 'bagging_fraction': 0.977105480861911, 'bagging_freq': 4, 'min_child_samples': 25, 'lambda_l1': 5.708058730647058e-08, 'lambda_l2': 0.004548381082969516}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:39,276] Trial 66 finished with value: 1972.229455713797 and parameters: {'num_leaves': 206, 'learning_rate': 0.02177045913510539, 'feature_fraction': 0.44632042241750014, 'bagging_fraction': 0.9984515650073239, 'bagging_freq': 3, 'min_child_samples': 11, 'lambda_l1': 1.7843233712584398e-08, 'lambda_l2': 0.0004896527452654608}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:40,985] Trial 67 finished with value: 1871.3747309394855 and parameters: {'num_leaves': 155, 'learning_rate': 0.06990414542350341, 'feature_fraction': 0.5355086292462597, 'bagging_fraction': 0.9529424137298905, 'bagging_freq': 4, 'min_child_samples': 40, 'lambda_l1': 1.6480073581665505e-07, 'lambda_l2': 0.0020247033711857875}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:43,086] Trial 68 finished with value: 1880.6962382073216 and parameters: {'num_leaves': 297, 'learning_rate': 0.07543250197517143, 'feature_fraction': 0.6019022497225721, 'bagging_fraction': 0.9285312553575672, 'bagging_freq': 3, 'min_child_samples': 29, 'lambda_l1': 6.67756348626315e-08, 'lambda_l2': 0.03390100370493983}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:44,655] Trial 69 finished with value: 1872.5852232639384 and parameters: {'num_leaves': 141, 'learning_rate': 0.07972737483937543, 'feature_fraction': 0.4011042797549639, 'bagging_fraction': 0.9797626688793488, 'bagging_freq': 3, 'min_child_samples': 25, 'lambda_l1': 1.0466355767042797e-08, 'lambda_l2': 0.00011395537474939641}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:46,122] Trial 70 finished with value: 1888.4773207277929 and parameters: {'num_leaves': 128, 'learning_rate': 0.08626477095760508, 'feature_fraction': 0.5057808720283516, 'bagging_fraction': 0.5436038621631685, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 3.817817755025026e-08, 'lambda_l2': 0.007258614686559124}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:47,795] Trial 71 finished with value: 1877.9242206644774 and parameters: {'num_leaves': 169, 'learning_rate': 0.09691461560823099, 'feature_fraction': 0.461935702890219, 'bagging_fraction': 0.9188157210556481, 'bagging_freq': 5, 'min_child_samples': 53, 'lambda_l1': 0.00027976795649832097, 'lambda_l2': 0.001435377719840933}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:49,146] Trial 72 finished with value: 1871.9679575131643 and parameters: {'num_leaves': 86, 'learning_rate': 0.0923019881117497, 'feature_fraction': 0.4401372034358844, 'bagging_fraction': 0.9581505166163237, 'bagging_freq': 5, 'min_child_samples': 45, 'lambda_l1': 1.4958594609594559e-06, 'lambda_l2': 5.5360045397196854e-06}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:50,421] Trial 73 finished with value: 1879.2249059942706 and parameters: {'num_leaves': 42, 'learning_rate': 0.08894172742291427, 'feature_fraction': 0.479924453221874, 'bagging_fraction': 0.9270450645717198, 'bagging_freq': 4, 'min_child_samples': 58, 'lambda_l1': 4.472673058902412e-07, 'lambda_l2': 0.2532477738649598}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:52,117] Trial 74 finished with value: 1869.9956467360794 and parameters: {'num_leaves': 158, 'learning_rate': 0.09607196651840758, 'feature_fraction': 0.4552101980853224, 'bagging_fraction': 0.9750521476340571, 'bagging_freq': 4, 'min_child_samples': 38, 'lambda_l1': 7.49353683218767e-08, 'lambda_l2': 3.0737203333902737e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:53,792] Trial 75 finished with value: 1870.7844162360257 and parameters: {'num_leaves': 181, 'learning_rate': 0.09828511358015532, 'feature_fraction': 0.41717841600564354, 'bagging_fraction': 0.9773909752339872, 'bagging_freq': 4, 'min_child_samples': 36, 'lambda_l1': 7.627333408048332e-08, 'lambda_l2': 1.3287740350676e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:55,444] Trial 76 finished with value: 1873.7550966563294 and parameters: {'num_leaves': 139, 'learning_rate': 0.08269286768782266, 'feature_fraction': 0.5556195011276376, 'bagging_fraction': 0.948431959952131, 'bagging_freq': 4, 'min_child_samples': 38, 'lambda_l1': 1.859170229774599e-07, 'lambda_l2': 3.2320011612714174e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:57,187] Trial 77 finished with value: 1871.2882310807518 and parameters: {'num_leaves': 207, 'learning_rate': 0.08839516237658834, 'feature_fraction': 0.43156974977750584, 'bagging_fraction': 0.9049201562906798, 'bagging_freq': 3, 'min_child_samples': 32, 'lambda_l1': 1.7094168183269407e-08, 'lambda_l2': 0.003907804078290644}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:51:58,928] Trial 78 finished with value: 1884.2368325144462 and parameters: {'num_leaves': 155, 'learning_rate': 0.09539679529265463, 'feature_fraction': 0.7906560205544366, 'bagging_fraction': 0.9994446444016188, 'bagging_freq': 4, 'min_child_samples': 41, 'lambda_l1': 3.546731672655787e-08, 'lambda_l2': 0.0007663403920590619}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:00,633] Trial 79 finished with value: 1876.2103238441948 and parameters: {'num_leaves': 161, 'learning_rate': 0.08474504617930816, 'feature_fraction': 0.44946642616142307, 'bagging_fraction': 0.96333153819391, 'bagging_freq': 2, 'min_child_samples': 27, 'lambda_l1': 6.358999640283192e-07, 'lambda_l2': 0.8474555205037236}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:02,241] Trial 80 finished with value: 1880.0740738278307 and parameters: {'num_leaves': 190, 'learning_rate': 0.09995086474699809, 'feature_fraction': 0.4713449302799314, 'bagging_fraction': 0.9803077601079393, 'bagging_freq': 1, 'min_child_samples': 33, 'lambda_l1': 9.479701452520762e-08, 'lambda_l2': 0.019726009631512754}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:03,899] Trial 81 finished with value: 1875.9748826140492 and parameters: {'num_leaves': 181, 'learning_rate': 0.09728172869059931, 'feature_fraction': 0.41346308102611884, 'bagging_fraction': 0.9744579077181938, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 5.977698882588532e-08, 'lambda_l2': 1.5654741639349673e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:05,520] Trial 82 finished with value: 1873.1431692018773 and parameters: {'num_leaves': 172, 'learning_rate': 0.09153500154754714, 'feature_fraction': 0.4160845092671112, 'bagging_fraction': 0.9397760716425881, 'bagging_freq': 4, 'min_child_samples': 35, 'lambda_l1': 8.429661292221304e-08, 'lambda_l2': 0.0554779888157234}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:07,258] Trial 83 finished with value: 1875.7092785243597 and parameters: {'num_leaves': 186, 'learning_rate': 0.09433663564946537, 'feature_fraction': 0.4341655808775409, 'bagging_fraction': 0.9884556568046514, 'bagging_freq': 4, 'min_child_samples': 44, 'lambda_l1': 2.447024753321885e-07, 'lambda_l2': 6.426332462998972e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:08,780] Trial 84 finished with value: 1880.8243907126534 and parameters: {'num_leaves': 116, 'learning_rate': 0.08115705146579356, 'feature_fraction': 0.6610368394088426, 'bagging_fraction': 0.9639058134890575, 'bagging_freq': 3, 'min_child_samples': 29, 'lambda_l1': 3.444970951750831e-08, 'lambda_l2': 1.2608618282380435e-06}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:10,548] Trial 85 finished with value: 1879.6483063729418 and parameters: {'num_leaves': 200, 'learning_rate': 0.08686587543823071, 'feature_fraction': 0.4599784894860182, 'bagging_fraction': 0.8741824430054459, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 1.6722245977446545e-08, 'lambda_l2': 1.2097502411755826e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:12,321] Trial 86 finished with value: 1876.3752842474548 and parameters: {'num_leaves': 227, 'learning_rate': 0.08976900206669332, 'feature_fraction': 0.400380325703436, 'bagging_fraction': 0.9478192752605886, 'bagging_freq': 5, 'min_child_samples': 50, 'lambda_l1': 1.5667903797858357e-07, 'lambda_l2': 0.00033771180816300004}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:13,989] Trial 87 finished with value: 1907.2806735218044 and parameters: {'num_leaves': 151, 'learning_rate': 0.031681958571448496, 'feature_fraction': 0.5229846510434653, 'bagging_fraction': 0.9857133258083068, 'bagging_freq': 3, 'min_child_samples': 30, 'lambda_l1': 2.866787090350202e-07, 'lambda_l2': 3.0465872354880046e-08}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:15,712] Trial 88 finished with value: 1873.3893801184952 and parameters: {'num_leaves': 178, 'learning_rate': 0.07818477478491259, 'feature_fraction': 0.487829069770716, 'bagging_fraction': 0.9696870925269336, 'bagging_freq': 4, 'min_child_samples': 39, 'lambda_l1': 1.0992611890411396e-07, 'lambda_l2': 5.97035006512652e-08}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:17,358] Trial 89 finished with value: 1873.4166603030067 and parameters: {'num_leaves': 164, 'learning_rate': 0.07383087437832271, 'feature_fraction': 0.4287305323154339, 'bagging_fraction': 0.9072095236841702, 'bagging_freq': 3, 'min_child_samples': 34, 'lambda_l1': 2.1879142729669967, 'lambda_l2': 3.241788735481289e-07}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:19,183] Trial 90 finished with value: 1875.5909664967514 and parameters: {'num_leaves': 220, 'learning_rate': 0.09833655510126531, 'feature_fraction': 0.41428972244202367, 'bagging_fraction': 0.9336185440104469, 'bagging_freq': 2, 'min_child_samples': 92, 'lambda_l1': 5.2495500520986734e-08, 'lambda_l2': 0.0013828777501485611}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:20,474] Trial 91 finished with value: 1878.5817379778443 and parameters: {'num_leaves': 63, 'learning_rate': 0.09608513773095351, 'feature_fraction': 0.45467159411958996, 'bagging_fraction': 0.6917125115429089, 'bagging_freq': 5, 'min_child_samples': 50, 'lambda_l1': 0.001835202499276093, 'lambda_l2': 1.836427859334579e-08}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:21,874] Trial 92 finished with value: 1870.5289041640451 and parameters: {'num_leaves': 79, 'learning_rate': 0.09361667562898521, 'feature_fraction': 0.4416480716230672, 'bagging_fraction': 0.9259926779040593, 'bagging_freq': 6, 'min_child_samples': 55, 'lambda_l1': 2.7492667741553638e-08, 'lambda_l2': 0.010642563153996195}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:23,318] Trial 93 finished with value: 1872.1827044584895 and parameters: {'num_leaves': 98, 'learning_rate': 0.09251354829754624, 'feature_fraction': 0.4396546014953118, 'bagging_fraction': 0.9539573804641064, 'bagging_freq': 6, 'min_child_samples': 43, 'lambda_l1': 1.5448387213510948e-08, 'lambda_l2': 0.006835717732933265}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:24,634] Trial 94 finished with value: 1885.2529506169126 and parameters: {'num_leaves': 80, 'learning_rate': 0.08547253640489101, 'feature_fraction': 0.5073151052211361, 'bagging_fraction': 0.613635183798925, 'bagging_freq': 7, 'min_child_samples': 56, 'lambda_l1': 4.1880882522522256e-08, 'lambda_l2': 0.025704638744854052}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:26,232] Trial 95 finished with value: 1870.6688280866883 and parameters: {'num_leaves': 131, 'learning_rate': 0.09284415154361897, 'feature_fraction': 0.47242789140415664, 'bagging_fraction': 0.988026035300481, 'bagging_freq': 4, 'min_child_samples': 46, 'lambda_l1': 2.3146522773071313e-08, 'lambda_l2': 0.003213284395982039}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:27,712] Trial 96 finished with value: 1868.1674908428597 and parameters: {'num_leaves': 133, 'learning_rate': 0.08321886515718684, 'feature_fraction': 0.4706783252737032, 'bagging_fraction': 0.9911181488294423, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 2.5004807668338144e-08, 'lambda_l2': 0.014527707072730107}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:29,197] Trial 97 finished with value: 1870.4020228446007 and parameters: {'num_leaves': 121, 'learning_rate': 0.08171371398895934, 'feature_fraction': 0.4917440560889628, 'bagging_fraction': 0.9985768805478712, 'bagging_freq': 1, 'min_child_samples': 52, 'lambda_l1': 1.0149658354799903e-08, 'lambda_l2': 0.12615570114069447}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:30,701] Trial 98 finished with value: 1874.052560665274 and parameters: {'num_leaves': 122, 'learning_rate': 0.08206928513255234, 'feature_fraction': 0.4950339810335439, 'bagging_fraction': 0.9984060544301874, 'bagging_freq': 1, 'min_child_samples': 52, 'lambda_l1': 1.220309945186454e-08, 'lambda_l2': 0.11082671136953051}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:32,308] Trial 99 finished with value: 1873.774069273541 and parameters: {'num_leaves': 137, 'learning_rate': 0.07605379983347857, 'feature_fraction': 0.5294941534707684, 'bagging_fraction': 0.9624340009762272, 'bagging_freq': 1, 'min_child_samples': 64, 'lambda_l1': 1.0543387486027374e-08, 'lambda_l2': 0.842590309833535}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:33,727] Trial 100 finished with value: 1873.1964545944445 and parameters: {'num_leaves': 112, 'learning_rate': 0.07218726547370652, 'feature_fraction': 0.477387939495163, 'bagging_fraction': 0.9720891100781864, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 1.437433824948514e-07, 'lambda_l2': 0.04313484506730189}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:35,128] Trial 101 finished with value: 1869.7661185678023 and parameters: {'num_leaves': 103, 'learning_rate': 0.083889500219306, 'feature_fraction': 0.4571180270716134, 'bagging_fraction': 0.9448174083771143, 'bagging_freq': 1, 'min_child_samples': 41, 'lambda_l1': 2.743161950657466e-08, 'lambda_l2': 0.011424769968310705}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:36,583] Trial 102 finished with value: 1874.9794074033725 and parameters: {'num_leaves': 123, 'learning_rate': 0.07868470791544864, 'feature_fraction': 0.45454967679228264, 'bagging_fraction': 0.9545755571648955, 'bagging_freq': 1, 'min_child_samples': 42, 'lambda_l1': 2.9959416070194e-08, 'lambda_l2': 0.013168183829861532}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:37,954] Trial 103 finished with value: 1874.3677741477297 and parameters: {'num_leaves': 103, 'learning_rate': 0.0839723704066083, 'feature_fraction': 0.4273944080857138, 'bagging_fraction': 0.9880949331217437, 'bagging_freq': 1, 'min_child_samples': 40, 'lambda_l1': 0.0006139809403315044, 'lambda_l2': 0.005119506527211556}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:39,532] Trial 104 finished with value: 1871.2188332107032 and parameters: {'num_leaves': 143, 'learning_rate': 0.07973385608361898, 'feature_fraction': 0.4670100899881401, 'bagging_fraction': 0.9407628883434964, 'bagging_freq': 1, 'min_child_samples': 27, 'lambda_l1': 7.452674202721248e-08, 'lambda_l2': 0.0023860985657672617}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:40,963] Trial 105 finished with value: 1872.8420728354315 and parameters: {'num_leaves': 110, 'learning_rate': 0.08718418562220939, 'feature_fraction': 0.5099167388257546, 'bagging_fraction': 0.8907799320707095, 'bagging_freq': 1, 'min_child_samples': 44, 'lambda_l1': 4.698447843905169e-08, 'lambda_l2': 0.09890063661199035}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:42,510] Trial 106 finished with value: 1873.253041685688 and parameters: {'num_leaves': 158, 'learning_rate': 0.08151139524212901, 'feature_fraction': 0.4930640275869671, 'bagging_fraction': 0.8031907389441386, 'bagging_freq': 1, 'min_child_samples': 50, 'lambda_l1': 1.7809238592391898e-08, 'lambda_l2': 0.19283691137078993}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:44,153] Trial 107 finished with value: 1868.8452819558424 and parameters: {'num_leaves': 150, 'learning_rate': 0.08869935600837872, 'feature_fraction': 0.4091460007658013, 'bagging_fraction': 0.9992952059495309, 'bagging_freq': 2, 'min_child_samples': 38, 'lambda_l1': 5.643663109634158e-07, 'lambda_l2': 0.025123910881982518}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:45,744] Trial 108 finished with value: 1874.4926985374532 and parameters: {'num_leaves': 147, 'learning_rate': 0.0893205234106891, 'feature_fraction': 0.40870750872056655, 'bagging_fraction': 0.9152346703318078, 'bagging_freq': 2, 'min_child_samples': 24, 'lambda_l1': 5.330564261494584e-07, 'lambda_l2': 0.021935212419624293}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:47,446] Trial 109 finished with value: 1871.6017896240005 and parameters: {'num_leaves': 168, 'learning_rate': 0.08466372792758864, 'feature_fraction': 0.4263485422744749, 'bagging_fraction': 0.9723954617884228, 'bagging_freq': 2, 'min_child_samples': 33, 'lambda_l1': 2.551724621070027e-07, 'lambda_l2': 0.009055971334226405}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:49,051] Trial 110 finished with value: 1868.2875518358846 and parameters: {'num_leaves': 132, 'learning_rate': 0.08813996112806781, 'feature_fraction': 0.40959464111614274, 'bagging_fraction': 0.9867793271036597, 'bagging_freq': 2, 'min_child_samples': 38, 'lambda_l1': 8.904143171209851e-07, 'lambda_l2': 0.043076231427237974}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:50,665] Trial 111 finished with value: 1868.131729692563 and parameters: {'num_leaves': 131, 'learning_rate': 0.08824898745219842, 'feature_fraction': 0.4097609866378083, 'bagging_fraction': 0.9854358296350517, 'bagging_freq': 2, 'min_child_samples': 36, 'lambda_l1': 1.3078524227403521e-06, 'lambda_l2': 0.040410873173483124}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:52,209] Trial 112 finished with value: 1873.6339552631541 and parameters: {'num_leaves': 127, 'learning_rate': 0.08624206330813966, 'feature_fraction': 0.40938503580511404, 'bagging_fraction': 0.9888943972247622, 'bagging_freq': 2, 'min_child_samples': 5, 'lambda_l1': 3.140568255075231e-06, 'lambda_l2': 0.043590280195182116}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:53,718] Trial 113 finished with value: 1871.3099343339852 and parameters: {'num_leaves': 135, 'learning_rate': 0.09052869718983578, 'feature_fraction': 0.43669312690198, 'bagging_fraction': 0.9999400994639277, 'bagging_freq': 2, 'min_child_samples': 31, 'lambda_l1': 1.3062767754504297e-06, 'lambda_l2': 0.017822879438187365}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:55,215] Trial 114 finished with value: 1872.6813871462614 and parameters: {'num_leaves': 101, 'learning_rate': 0.08813776368240941, 'feature_fraction': 0.4032656175797865, 'bagging_fraction': 0.9443171739188876, 'bagging_freq': 2, 'min_child_samples': 41, 'lambda_l1': 6.574732544858575e-07, 'lambda_l2': 0.03091384841038785}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:56,841] Trial 115 finished with value: 1870.774374025987 and parameters: {'num_leaves': 139, 'learning_rate': 0.0769376033246846, 'feature_fraction': 0.41999629113693004, 'bagging_fraction': 0.9612077648597626, 'bagging_freq': 2, 'min_child_samples': 36, 'lambda_l1': 7.248161866448681e-06, 'lambda_l2': 1.9182769258197835e-05}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:52:58,478] Trial 116 finished with value: 1867.7248335262443 and parameters: {'num_leaves': 129, 'learning_rate': 0.08277565478365673, 'feature_fraction': 0.449451666262015, 'bagging_fraction': 0.9828974332638452, 'bagging_freq': 2, 'min_child_samples': 46, 'lambda_l1': 3.0046806926216853e-07, 'lambda_l2': 0.07006359799387109}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:00,120] Trial 117 finished with value: 1870.5140896754187 and parameters: {'num_leaves': 131, 'learning_rate': 0.08371010082622692, 'feature_fraction': 0.44635583840310533, 'bagging_fraction': 0.9817683860433915, 'bagging_freq': 2, 'min_child_samples': 45, 'lambda_l1': 1.036004634774581e-06, 'lambda_l2': 0.04947625929764585}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:01,664] Trial 118 finished with value: 1867.8779517450407 and parameters: {'num_leaves': 108, 'learning_rate': 0.08763589678999673, 'feature_fraction': 0.4250126314965959, 'bagging_fraction': 0.9339859957442256, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 2.174226799825987e-06, 'lambda_l2': 0.07399533896474943}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:03,230] Trial 119 finished with value: 1870.7995517852182 and parameters: {'num_leaves': 117, 'learning_rate': 0.08867332762780306, 'feature_fraction': 0.42583249236146237, 'bagging_fraction': 0.9662380588186031, 'bagging_freq': 2, 'min_child_samples': 48, 'lambda_l1': 2.210741345149932e-06, 'lambda_l2': 0.08674053572467288}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:04,731] Trial 120 finished with value: 1870.0585560744917 and parameters: {'num_leaves': 89, 'learning_rate': 0.09093497530555404, 'feature_fraction': 0.43352193882306655, 'bagging_fraction': 0.9301169748396068, 'bagging_freq': 2, 'min_child_samples': 39, 'lambda_l1': 3.983521597567035e-06, 'lambda_l2': 0.1927660838280574}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:06,713] Trial 121 finished with value: 1871.0188173808115 and parameters: {'num_leaves': 264, 'learning_rate': 0.08569347370552878, 'feature_fraction': 0.45945491026128865, 'bagging_fraction': 0.946958259186497, 'bagging_freq': 2, 'min_child_samples': 46, 'lambda_l1': 3.916238084983032e-07, 'lambda_l2': 0.07265366707074562}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:08,241] Trial 122 finished with value: 1869.1448986212038 and parameters: {'num_leaves': 106, 'learning_rate': 0.07949119419734842, 'feature_fraction': 0.41477552999701334, 'bagging_fraction': 0.9533277221542884, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 1.2678870437074006e-05, 'lambda_l2': 0.03292608852067976}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:09,798] Trial 123 finished with value: 1869.5135814395123 and parameters: {'num_leaves': 111, 'learning_rate': 0.08044535723572602, 'feature_fraction': 0.414384241445043, 'bagging_fraction': 0.9822012983455318, 'bagging_freq': 2, 'min_child_samples': 43, 'lambda_l1': 1.3529836381125172e-05, 'lambda_l2': 0.03243804254905656}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:11,340] Trial 124 finished with value: 1870.9579070767834 and parameters: {'num_leaves': 107, 'learning_rate': 0.07995558665110714, 'feature_fraction': 0.4003747909269577, 'bagging_fraction': 0.9842263054943006, 'bagging_freq': 2, 'min_child_samples': 43, 'lambda_l1': 1.9081952004256867e-06, 'lambda_l2': 0.5630570773244419}. Best is trial 46 with value: 1866.949954410061.
# [I 2025-05-06 17:53:12,973] Trial 125 finished with value: 1866.089164255119 and parameters: {'num_leaves': 146, 'learning_rate': 0.07470350805520398, 'feature_fraction': 0.411448374406298, 'bagging_fraction': 0.9740684045160495, 'bagging_freq': 2, 'min_child_samples': 35, 'lambda_l1': 1.844912451192401e-05, 'lambda_l2': 0.031981947771846216}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:14,627] Trial 126 finished with value: 1871.839895667385 and parameters: {'num_leaves': 147, 'learning_rate': 0.07525970938757459, 'feature_fraction': 0.42485942382216957, 'bagging_fraction': 0.969832144888598, 'bagging_freq': 2, 'min_child_samples': 34, 'lambda_l1': 2.642075927443953e-05, 'lambda_l2': 0.00022935712145724492}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:16,241] Trial 127 finished with value: 1870.0655504343338 and parameters: {'num_leaves': 129, 'learning_rate': 0.0705977553681532, 'feature_fraction': 0.4351935391768231, 'bagging_fraction': 0.9582456949545705, 'bagging_freq': 2, 'min_child_samples': 38, 'lambda_l1': 4.59748212454762e-06, 'lambda_l2': 0.0584029669453346}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:17,881] Trial 128 finished with value: 1873.7542619816936 and parameters: {'num_leaves': 144, 'learning_rate': 0.053136230052691885, 'feature_fraction': 0.41186500083348465, 'bagging_fraction': 0.9904142918283467, 'bagging_freq': 2, 'min_child_samples': 40, 'lambda_l1': 8.03250746855507e-07, 'lambda_l2': 0.18974852232690234}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:19,692] Trial 129 finished with value: 1870.6753561143328 and parameters: {'num_leaves': 172, 'learning_rate': 0.07795327054331093, 'feature_fraction': 0.44400119788751247, 'bagging_fraction': 0.9712261014406276, 'bagging_freq': 2, 'min_child_samples': 47, 'lambda_l1': 6.498234000391532e-05, 'lambda_l2': 0.0004846866214821942}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:21,520] Trial 130 finished with value: 1882.1291934566016 and parameters: {'num_leaves': 149, 'learning_rate': 0.08729204756646784, 'feature_fraction': 0.9135080564208633, 'bagging_fraction': 0.9550738628887331, 'bagging_freq': 2, 'min_child_samples': 35, 'lambda_l1': 3.4712174781044905e-07, 'lambda_l2': 0.029029291691865373}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:23,096] Trial 131 finished with value: 1867.9174701572788 and parameters: {'num_leaves': 120, 'learning_rate': 0.07405063665737739, 'feature_fraction': 0.41306582798580244, 'bagging_fraction': 0.9820231895861006, 'bagging_freq': 2, 'min_child_samples': 43, 'lambda_l1': 1.0412274670153089e-05, 'lambda_l2': 0.040080061540188894}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:24,693] Trial 132 finished with value: 1868.3809734324936 and parameters: {'num_leaves': 123, 'learning_rate': 0.07332358634072263, 'feature_fraction': 0.41862715672869893, 'bagging_fraction': 0.9865380498268368, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 1.0947251646450824e-05, 'lambda_l2': 0.07798970570492195}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:26,282] Trial 133 finished with value: 1874.0818303769497 and parameters: {'num_leaves': 120, 'learning_rate': 0.06758360940059899, 'feature_fraction': 0.41919599023002596, 'bagging_fraction': 0.9881564930513657, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 3.36042999717339e-05, 'lambda_l2': 0.09403296479753093}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:27,905] Trial 134 finished with value: 1873.6151802710217 and parameters: {'num_leaves': 136, 'learning_rate': 0.07422045060002562, 'feature_fraction': 0.44176138160168743, 'bagging_fraction': 0.9781499008282305, 'bagging_freq': 2, 'min_child_samples': 45, 'lambda_l1': 7.379861999587933e-06, 'lambda_l2': 0.01734014824067806}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:29,497] Trial 135 finished with value: 1871.563421029291 and parameters: {'num_leaves': 125, 'learning_rate': 0.06336512499818502, 'feature_fraction': 0.4004041972838502, 'bagging_fraction': 0.997301822649068, 'bagging_freq': 2, 'min_child_samples': 49, 'lambda_l1': 1.9466158666111326e-05, 'lambda_l2': 0.04125969261820061}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:31,123] Trial 136 finished with value: 1870.6639592689914 and parameters: {'num_leaves': 141, 'learning_rate': 0.06952548413655923, 'feature_fraction': 0.4135205454571039, 'bagging_fraction': 0.9682256610162923, 'bagging_freq': 2, 'min_child_samples': 36, 'lambda_l1': 1.0109188816655285e-05, 'lambda_l2': 0.39692590506186837}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:32,760] Trial 137 finished with value: 1873.6210213143333 and parameters: {'num_leaves': 130, 'learning_rate': 0.07711315352151539, 'feature_fraction': 0.4281071577513872, 'bagging_fraction': 0.9806536960113718, 'bagging_freq': 2, 'min_child_samples': 32, 'lambda_l1': 5.7187169714651234e-05, 'lambda_l2': 0.14784377281189576}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:34,393] Trial 138 finished with value: 1871.109601737444 and parameters: {'num_leaves': 152, 'learning_rate': 0.07368750351260041, 'feature_fraction': 0.46822792888469167, 'bagging_fraction': 0.9331900652355931, 'bagging_freq': 2, 'min_child_samples': 44, 'lambda_l1': 1.3259058180667535e-05, 'lambda_l2': 0.05661132903808549}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:35,926] Trial 139 finished with value: 1869.0797105946235 and parameters: {'num_leaves': 98, 'learning_rate': 0.06542031111007199, 'feature_fraction': 0.4475942704683635, 'bagging_fraction': 0.9592125372815402, 'bagging_freq': 2, 'min_child_samples': 39, 'lambda_l1': 5.33838613310758e-06, 'lambda_l2': 0.0063679927990894026}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:37,461] Trial 140 finished with value: 1871.551792815282 and parameters: {'num_leaves': 94, 'learning_rate': 0.08288626138154945, 'feature_fraction': 0.47832015618115614, 'bagging_fraction': 0.9649350980626358, 'bagging_freq': 2, 'min_child_samples': 29, 'lambda_l1': 1.2516455036802937e-06, 'lambda_l2': 0.005872625126534182}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:39,015] Trial 141 finished with value: 1875.0443933269535 and parameters: {'num_leaves': 98, 'learning_rate': 0.059939580165918695, 'feature_fraction': 0.4447887164752049, 'bagging_fraction': 0.9909226205438203, 'bagging_freq': 2, 'min_child_samples': 39, 'lambda_l1': 5.2028408324684874e-06, 'lambda_l2': 0.025055070407300057}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:40,726] Trial 142 finished with value: 1869.6982315818514 and parameters: {'num_leaves': 114, 'learning_rate': 0.07240570919796638, 'feature_fraction': 0.42116678717555867, 'bagging_fraction': 0.9996548817570188, 'bagging_freq': 2, 'min_child_samples': 78, 'lambda_l1': 2.366709629103319e-06, 'lambda_l2': 0.008478130305115822}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:42,401] Trial 143 finished with value: 1870.4330319727037 and parameters: {'num_leaves': 162, 'learning_rate': 0.07555038048991192, 'feature_fraction': 0.41116036649810317, 'bagging_fraction': 0.954480736598045, 'bagging_freq': 2, 'min_child_samples': 41, 'lambda_l1': 9.649058417208454e-06, 'lambda_l2': 0.014293872421180555}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:43,859] Trial 144 finished with value: 1873.9052127102211 and parameters: {'num_leaves': 70, 'learning_rate': 0.07844086783833666, 'feature_fraction': 0.4331068474032643, 'bagging_fraction': 0.9755726345865307, 'bagging_freq': 2, 'min_child_samples': 46, 'lambda_l1': 0.00013266015761526786, 'lambda_l2': 0.07793870906527373}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:45,485] Trial 145 finished with value: 1871.402267624985 and parameters: {'num_leaves': 124, 'learning_rate': 0.08560834615670693, 'feature_fraction': 0.45146271533961796, 'bagging_fraction': 0.9393554261636632, 'bagging_freq': 2, 'min_child_samples': 39, 'lambda_l1': 2.5290355987529996e-06, 'lambda_l2': 0.0016703379739094841}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:47,162] Trial 146 finished with value: 1873.3973828195458 and parameters: {'num_leaves': 135, 'learning_rate': 0.07135397403728683, 'feature_fraction': 0.4375950627095522, 'bagging_fraction': 0.9841285735956005, 'bagging_freq': 2, 'min_child_samples': 37, 'lambda_l1': 2.208120813972185e-05, 'lambda_l2': 0.03612688683336856}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:48,593] Trial 147 finished with value: 1881.9224976646462 and parameters: {'num_leaves': 119, 'learning_rate': 0.04558252779612008, 'feature_fraction': 0.42327997078463103, 'bagging_fraction': 0.9610047640380264, 'bagging_freq': 1, 'min_child_samples': 42, 'lambda_l1': 3.912194555361896e-05, 'lambda_l2': 0.0008500985918582241}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:50,177] Trial 148 finished with value: 1874.393491504676 and parameters: {'num_leaves': 140, 'learning_rate': 0.07928681497588513, 'feature_fraction': 0.40058535138117884, 'bagging_fraction': 0.9741108373609829, 'bagging_freq': 3, 'min_child_samples': 34, 'lambda_l1': 7.065881895528566e-06, 'lambda_l2': 0.021147178945390744}. Best is trial 125 with value: 1866.089164255119.
# [I 2025-05-06 17:53:51,883] Trial 149 finished with value: 1873.5633718003032 and parameters: {'num_leaves': 155, 'learning_rate': 0.06485005702741692, 'feature_fraction': 0.4629488415700058, 'bagging_fraction': 0.9477609615143838, 'bagging_freq': 2, 'min_child_samples': 47, 'lambda_l1': 5.844609599511153e-06, 'lambda_l2': 0.004166530340321124}. Best is trial 125 with value: 1866.089164255119.
# Best trial:
#   RMSE: 1866.089164255119
#   Params:
#     num_leaves: 146
#     learning_rate: 0.07470350805520398
#     feature_fraction: 0.411448374406298
#     bagging_fraction: 0.9740684045160495
#     bagging_freq: 2
#     min_child_samples: 35
#     lambda_l1: 1.844912451192401e-05
#     lambda_l2: 0.031981947771846216
